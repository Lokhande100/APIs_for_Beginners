# %% [markdown]
# <a href="https://colab.research.google.com/github/Lokhande10/APIs_for_Beginners/blob/main/REST_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
REST APIs # Representation state transfer
# Architechture

#https://en.wikipedia.org/wiki/Representational_state_transfer............................Info URL

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
HTTP Verbs used for APIs

# %% [markdown]
# GET
# Post
# Push
# Patch
# Delete

# %%
# For coding Json format is uded for APIs

# %%
CRUD Rule for APP development

# %% [markdown]
# ![image.png](data:image/png;base64,...)
