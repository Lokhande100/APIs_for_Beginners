# %% [markdown]
# <a href="https://colab.research.google.com/github/Lokhande10/APIs_for_Beginners/blob/main/Twilio_app_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install twilio
# Out:
# Collecting twilio
#   Downloading twilio-7.6.0-py2.py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 4.2 MB/s
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from twilio) (2018.9)
# Collecting PyJWT<3.0.0,>=2.0.0
#   Downloading PyJWT-2.3.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from twilio) (2.23.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->twilio) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->twilio) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->twilio) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.0.0->twilio) (1.24.3)
# Installing collected packages: PyJWT, twilio
# Successfully installed PyJWT-2.3.0 twilio-7.6.0

# %%
# Programmable SMS

# %%
from twilio.rest import Client

# %%
# Download the helper library from https://www.twilio.com/docs/python/install
import os
from twilio.rest import Client


# Find your Account SID and Auth Token at twilio.com/console
# and set the environment variables. See http://twil.io/secure
account_sid = os.environ['AC3023525a59e26a8d37caac3862e738db']
auth_token = os.environ['36c0a3d289472d4779d2f66c1534e4f4']
client = Client(account_sid, auth_token)

message = client.messages \
                .create(
                     body="Hi this is nikhil",
                     from_='+18597192560',
                     to='+919511224375'
                 )

print(message.sid)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-a57397f230c2> in <module>()
#       6 # Find your Account SID and Auth Token at twilio.com/console
#       7 # and set the environment variables. See http://twil.io/secure
# ----> 8 account_sid = os.environ['AC3023525a59e26a8d37caac3862e738db']
#       9 auth_token = os.environ['36c0a3d289472d4779d2f66c1534e4f4']
#      10 client = Client(account_sid, auth_token)
#
# /usr/lib/python3.7/os.py in __getitem__(self, key)
#     679         except KeyError:
#     680             # raise KeyError with the original key value
# --> 681             raise KeyError(key) from None
#     682         return self.decodevalue(value)
#     683
#
# KeyError: 'AC3023525a59e26a8d37caac3862e738db'

# %%
# Install the twilio-cli from https://twil.io/cli

twilio api:core:messages:create \
    --body "Join Earth's mightiest heroes. Like Kevin Bacon." \
    --from +15017122661 \
    --to +15558675310
